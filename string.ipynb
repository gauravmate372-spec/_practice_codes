# %%
a = 'hello'
print(a[1]) #indexing
# Out:
# e

# %%
s = 'Hello how are you?'
print(s[0:5]) #slicing of strings
# Out:
# Hello

# %%
s = 'Hello student'
print(s[::-1]) #reverse a list
# Out:
# tneduts olleH

# %%
print(len(a)) #length of string
# Out:
# 5

# %%
b = 'Hello how are you?'
print(b.upper()) #convert all string into a upper method
# Out:
# HELLO HOW ARE YOU?

# %%
print(b.lower()) # convert the all string into a lower method
# Out:
# hello how are you?

# %%
c = 'Hello how are you?'
print(c.replace('Hello','Hi'))
# Out:
# Hi how are you?
