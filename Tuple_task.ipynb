# %%
student = ('Gaurav',20,(85,90,95))

# %%
student[0]
# Out:
# 'Gaurav'

# %%
student[2][1]
# Out:
# 90

# %%
student[2][0]
# Out:
# 85

# %%
student[::-1]
# Out:
# ((85, 90, 95), 20, 'Gaurav')

# %%
student[2][0] + student [2][1] + student[2][2]
# Out:
# 270
