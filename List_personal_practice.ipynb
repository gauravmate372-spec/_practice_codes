# %%
mylist = ['apple' , 'banana' , 'cherry']
print(mylist)
print(type(mylist)) #creating a list
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
mylist = ['apple' , 'banana' , 'apple' , 'cherry']
print(mylist) #list allow duplicate values
# Out:
# ['apple', 'banana', 'apple', 'cherry']

# %%
a = [1,2,3,4,5,6,7,8,9,'Hello', 'student']
print(len(a)) #length of a list
# Out:
# 11

# %%
thislist = [23,34,3,3,4,32,32,3,3,45,4,54,5]
print(thislist[1]) #accessing a list
# Out:
# 34

# %%
print(thislist[0:6])
print(thislist[0:8:2]) #this is slicing a list
# Out:
# [23, 34, 3, 3, 4, 32]
# [23, 3, 4, 32]

# %%
newlist = ['apple', 'banana', 'cherry']
newlist[1] = 'watermelon'
print(newlist) #change items
# Out:
# ['apple', 'watermelon', 'cherry']

# %%
a = [12,34,35,46,5,38,4]
a[1:4] = ['books', 'cherry', 'paper']
print(a) #change a range of item values
# Out:
# [12, 'books', 'cherry', 'paper', 5, 38, 4]

# %%
b = ['apple', 'cherry', 'data']
b.append('banana')
print(b)
# Out:
# ['apple', 'cherry', 'data', 'banana']

# %%
i = [2,3,4,34,5,6]
print(len(i))
a = 0:
for i in range(13):
    print()
# Out:
#   Cell In[13], line 3
#     a = 0:
#          ^
# SyntaxError: invalid syntax
