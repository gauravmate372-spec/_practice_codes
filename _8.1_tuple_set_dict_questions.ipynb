# %%
#1
t = (1,2,3)

# %%
t[1] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 t[1] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = (1, 1, 2, 3, 1)

# %%
y.count(1)
# Out:
# 3

# %%
y = (10, 20, 7, 40)

# %%
(y[2])
# Out:
# 7

# %%
u = (10, 20,(50,60),90)

# %%
(u[2][1])
# Out:
# 60

# %%
set([1,2,2,3,4,4,4])
# Out:
# {1, 2, 3, 4}

# %%
set : (100)

# %%
set = {10,20,30}

# %%
set.remove(10)

# %%
set
# Out:
# {20, 30}

# %%
s1 = {10,20}

# %%
s2 = {30,40}

# %%
s1. union(s2)
# Out:
# {10, 20, 30, 40}

# %%
s1 . interaction (s2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s1 . interaction (s2)
#
# AttributeError: 'set' object has no attribute 'interaction'

# %%
d = {'name' : 'sham' , 'age':20}

# %%
(d['age'])
# Out:
# 20

# %%
d['name']
# Out:
# 'sham'

# %%
d
# Out:
# {'name': 'sham', 'age': 20}

# %%
d.pop('name')
# Out:
# 'sham'

# %%
d
# Out:
# {'age': 20}

# %%
d['age'] = 21

# %%
d
# Out:
# {'age': 21}

# %%
d.values
# Out:
# <function dict.values()>

# %%
d.items
# Out:
# <function dict.items()>

# %%
list = [1,2,3]

# %%
list
# Out:
# [1, 2, 3]

# %%
result = {'score':{'math':85,'science':88}}

# %%
result['score']['math']
# Out:
# 85

# %%
result['score']['science']
# Out:
# 88

# %%
t = (1,2,3,4)

# %%
len(t)
# Out:
# 4

# %%
t[0]
# Out:
# 1

# %%
d = {1:2,4:3}

# %%
d
# Out:
# {1: 2, 4: 3}

# %%
import pandas as pd
