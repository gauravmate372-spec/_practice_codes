# %%
l = [10,20,30,40,50,60,70,80]

# %%
 l[2:5]
# Out:
# [30, 40, 50]

# %%
l[:4]
l[5:]
l[::2]
l[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[-4:-1]
# Out:
# [50, 60, 70]

# %%
l = [10,20,30,40,50,60,70,80]

# %%
l[6:1:-2]
# Out:
# [70, 50, 30]

# %%
l[-3]
# Out:
# 60

# %%
nested = [1,2,[100,200,[300,400]],5]

# %%
2
# Out:
# 2

# %%
nested[2][1]
# Out:
# 200

# %%
nested[2][2][1]
# Out:
# 400

# %%
nested[2][1] = 250

# %%
nested
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
nested[2][0:2]
# Out:
# [100, 250]

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]

# %%
data[1]
# Out:
# [4, 5, 6]

# %%
[5,6]
# Out:
# [5, 6]

# %%
data[-1][-1]
# Out:
# 9

# %%
l = [1,2,3,4,5]
l[1:4] = l[1:4][::-1]

# %%
l
# Out:
# [1, 4, 3, 2, 5]

# %%
my_list = ["hello",[1,2,3,4,5][0:2]]

# %%
my_list
# Out:
# ['hello', [1, 2]]
