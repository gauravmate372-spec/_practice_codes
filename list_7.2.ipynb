# %%
slice = [10,20,30,40,50,60,70,80]

# %%
slice
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
slice[2:5]
# Out:
# [30, 40, 50]

# %%
slice[:4]
# Out:
# [10, 20, 30, 40]

# %%
slice[5:]
# Out:
# [60, 70, 80]

# %%
slice[::2]
# Out:
# [10, 30, 50, 70]

# %%
slice[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
slice[4:-1]
# Out:
# [50, 60, 70]

# %%
slice[6:1:-2]
# Out:
# [70, 50, 30]

# %%
slice[5:8]
# Out:
# [60, 70, 80]

# %%
nested = [1, 2 [100, 200 [300, 400]], 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 nested = [1, 2 [100, 200 [300, 400]], 5]
#
# TypeError: 'int' object is not subscriptable

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]

# %%
data[1]
# Out:
# [4, 5, 6]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %%
data[2][2]
# Out:
# 9

# %%
x = [1,2,3]

# %%
x.append([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x.extend([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %%
z = [10,20,30,40,50,60,70,80,90]

# %%
z[-3::-1]
# Out:
# [70, 60, 50, 40, 30, 20, 10]

# %%
z=[10,20,30,40,50]

# %%
z[1:4]
# Out:
# [20, 30, 40]

# %%
nested = ['2',nested[1:4]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 nested = ['2',nested[1:4]]
#
# NameError: name 'nested' is not defined
