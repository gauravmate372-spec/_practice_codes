# %%
my_tuple = (1,2,3)

# %%
my_tuple #creating a tuple
# Out:
# (1, 2, 3)

# %%
my_tuple = (1,'hello','2.3',4+5j)

# %%
my_tuple
# Out:
# (1, 'hello', '2.3', (4+5j))

# %%
a = (2,3,4,'hello',('ok'))

# %%
a
# Out:
# (2, 3, 4, 'hello', 'ok')

# %%
a = tuple(('a','b','c'))
print(a)
print(type(a))
# Out:
# ('a', 'b', 'c')
# <class 'tuple'>

# %%
a = [34,45,56,6,6,3]
print(a[3])
# Out:
# 6

# %%
print('gaurav')
# Out:
# gaurav

# %%
a = (32,34,3,43,4,3,43,4,3,3,4)
print(a[0:5])
print(a[::2])
# Out:
# (32, 34, 3, 43, 4)
# (32, 3, 4, 43, 3, 4)

# %%
a = (1,2,3,4,5,6,7,8,)

# %%
a[::-1]
# Out:
# (8, 7, 6, 5, 4, 3, 2, 1)

# %%
a[::]
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
a[3:]
# Out:
# (4, 5, 6, 7, 8)

# %%
a[:4]
# Out:
# (1, 2, 3, 4)

# %%
a[-2:-5]
# Out:
# ()

# %%
a = (1,2,3,4,5,6,7,8)
y = list(a)
y.append(9)
a = tuple(y)
print(a)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
this_tuple = ('a','b','c')
for i in this_tuple:
    print(i)
# Out:
# a
# b
# c

# %%
a = ('a','b','c')
b = (1,2,3)
c = a+b

# %%
c
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
a = ['apple','banana','cherry']
b = a*3

# %%
b
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  'apple',
#  'banana',
#  'cherry',
#  'apple',
#  'banana',
#  'cherry']

# %%
T = (1,2,3,4,5,6)

# %%
T*2
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
T+T+T
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
len(T)
# Out:
# 6

# %%
T = ()
i = 0
while i<5:
    num=int(input('enter the values please'))
