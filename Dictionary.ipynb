# %%
student = {
    'name': 'Gaurav',
    'age' :20,
    'course' : 'BBA (CA)'
}

# %%
student
# Out:
# {'name': 'Gaurav', 'age': 20, 'course': 'BBA (CA)'}

# %%
student = {'name': 'Gaurav', 'age' : 20}
student['city'] = 'PUNE'

# %%
student
# Out:
# {'name': 'Gaurav', 'age': 20, 'city': 'PUNE'}

# %%
student['age'] = 21

# %%
student
# Out:
# {'name': 'Gaurav', 'age': 21, 'city': 'PUNE'}

# %%
del student['age']

# %%
student.keys()
# Out:
# dict_keys(['name', 'city'])

# %%
print (student.values())
# Out:
# dict_values(['Gaurav', 'PUNE'])

# %%
print('name' in student)
# Out:
# True

# %%
student = {'name':'Gaurav','age' : 20}
new_student = student.copy()

# %%
new_student
# Out:
# {'name': 'Gaurav', 'age': 20}

# %%
student = {'name':'Gaurav','age' : 20}
for value in student.values():
    print(value)
# Out:
# Gaurav
# 20
