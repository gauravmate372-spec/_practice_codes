# %%
def even_odd(n):
    try:
        if n % 2 == 0:
            return 'Even number', n
        else:
            return 'Odd number', n
    except Exception as e:
        print('Error in even_odd function')
        print(e)
        
print(even_odd(10))
# Out:
# ('Even number', 10)

# %%
def divide(a, b):
    try:
        return a / b
    except Exception as e:
        print("Error in divide function")
        print(e)
print(divide(10,0))
# Out:
# Error in divide function
# division by zero
# None

# %%
def square(n):
    try:
        return n ** 2
    except Exception as e:
        print('error in square function')
print(square('abc'))
# Out:
# error in square function
# None

# %%
def largest(a, b):
    try:
        if a > b:
            return a
        else:
            return b
    except Exception as e:
        print('error in largest function')
        print(e)
print(largest(10, 20))
# Out:
# 20

# %%
def read_file(filename):
    try:
        with open(filename, 'r') as f:
            return f.read()
    except Exception as e:
        print('error in read_file function')
        print(e)
print(read_file('data.txt'))
# Out:
# error in read_file function
# [Errno 2] No such file or directory: 'data.txt'
# None

# %%
def get_element(lst, index):
    try:
        return lst[index]
    except Exception as e:
        print('error in get_element function')
        print(e)
numbers = [10, 20, 30]
print(get_element(numbers,5))
# Out:
# error in get_element function
# list index out of range
# None
