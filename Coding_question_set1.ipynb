# %%
num = 4
a = str(num)

# %%
num = '4'

# %%
type(num)
# Out:
# str

# %%
a = 5
a == 5
# Out:
# True

# %%
10 % 2
10 % 3
# Out:
# 1

# %%
3 * 'Hello'
# Out:
# 'HelloHelloHello'

# %%
first_name = 'gaurav'
last_name = 'mate'

# %%
first_name + last_name
# Out:
# 'gauravmate'
