# %% [raw]
# #1. Deep indexing practice

# %%
data = ["a" , "b" , ["c" , ["d" , "e" , "target"] ,"f"], "g"]
print(data[2][1][2])
# Out:
# target

# %% [raw]
# #2 Append

# %%
colors1 = ["red","blue"]
colors1.append(["green","yellow"])
print(colors1)
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %% [raw]
# #extend

# %%
colors2 = ["red","blue"]
colors2.extend(["green","yellow"])
print(colors2)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [raw]
# #3. Matrix Access

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
print (matrix[1][2])
# Out:
# 6

# %% [raw]
# #4. using insert()

# %%
nums = [10,20,40]
nums.insert(2,30)
print(nums)
# Out:
# [10, 20, 30, 40]

# %% [raw]
# #5. Mixed Data Types

# %%
mixed = [1,"python",[True , False]]
mixed[2][1] = None
print(mixed)
# Out:
# [1, 'python', [True, None]]

# %% [raw]
# part 1: Nested list indexing

# %%
nested = [1,[2,[3,[4,5,6]],7]]
print(nested[1][0])
print(nested[1][1][1])
print(nested[1][1][1][1])
# Out:
# 2
# [4, 5, 6]
# 5

# %% [raw]
# #Matrix example

# %%
matrix = [[10,20,30],[40,50,60],[70,80,90]]
print(matrix[1]) 
print(matrix[2][2])
print(matrix[1][0])
# Out:
# [40, 50, 60]
# 90
# 40

# %% [raw]
# part 2: List methods

# %%
#append()
fruits = ["apple" , "banana"]
fruits.append(["kiwi" , "mango"])
print(fruits)
# Out:
# ['apple', 'banana', ['kiwi', 'mango']]

# %%
#extend
fruits = ["apple" , "banana"]
fruits.extend(["kiwi" , "mango"])
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %%
#insert
nums = [10,20,30,40]
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 30, 40]

# %% [raw]
# part 3:Advanced practice challenges

# %%
#1
l = [5,6,[7,8,9],10]

# %%
(l[2][1])
# Out:
# 8

# %%
#2
data = [1,2,[3,[4,5]]]

# %%
data.extend([3,[4,5]])

# %%
data
# Out:
# [1, 2, [3, [4, 5]], 3, [4, 5]]

# %%
#3
x = [10,[20,"hello"]]
x[1][1]
# Out:
# 'hello'

# %%
x
# Out:
# [10, [20, 'hello']]

# %%
#4
p = [1,2,3]
p.insert(7[7])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 #4
#       2 p = [1,2,3]
# ----> 3 p.insert(7[7])
#
# TypeError: 'int' object is not subscriptable

# %%
l
# Out:
# [1, 2, 3]

# %%
#5
a = [1,2]
b = [3,4]
a.append(b)

# %%
a
# Out:
# [1, 2, [3, 4]]

# %%
(len(a))
# Out:
# 3

# %%
a
(len(a))
# Out:
# 3
